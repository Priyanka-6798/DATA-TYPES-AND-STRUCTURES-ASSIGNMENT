# %% [markdown]
# ##DATA TYPES AND STRUCTURES ASSIGNMENTS
#
#
# 1. What are data structures, and why are they important?
#
# ANS: Data structures are ways of organizing and storing data in a computer so that it can be accessed and modified efficiently. They are important because they improve performance of algorithms, and help in solving complex problems.
#
# 2. Explain the difference between mutable and immutable data types with examples.
#
# ANS: Mutable data types can be changed after creation (e.g., lists, dictionaries, sets). Immutable data types cannot be changed after creation (e.g., integers, strings, tuples).
#
# Example: A list [1, 2, 3] can be modified (mutable), while a tuple (1, 2, 3) cannot (immutable).
#
# 3. What are the main differences between lists and tuples in Python?
#
# ANS: Lists are mutable (can be modified), use square brackets [], and are generally used for collections of similar items. Tuples are immutable (cannot be modified), use parentheses (), and are often used for heterogeneous data or fixed collections.
#
# 4. Describe how dictionaries store data.
#
# ANS: Dictionaries store data as key-value pairs, where each key is unique and maps to a value. They are implemented using hash tables for efficient lookup.
#
# 5. Why might you use a set instead of a list in Python?
#
# ANS: Sets are used when you need to store unique elements and perform operations like union, intersection, or difference. They also provide faster membership testing compared to lists.
#
# 6. What is a string in Python, and how is it different from a list?
#
# ANS: A string is a sequence of characters, immutable, and typically used for text. A list is a sequence of elements, mutable, and can contain any data type. Strings are indexed like lists but cannot be modified in-place.
#
# 7. How do tuples ensure data integrity in Python?
#
# ANS: Tuples are immutable, meaning their elements cannot be changed after creation. This ensures that the data remains constant and prevents accidental modifications.
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#
# ANS: A hash table is a data structure that maps keys to values using a hash function. Python dictionaries are implemented using hash tables, allowing for fast key-value lookups.
#
# 9. Can lists contain different data types in Python?
#
# ANS: Yes, lists can contain elements of different data types, such as integers, strings.
#
# 10. Explain why strings are immutable in Python.
#
# ANS:Strings are immutable to ensure security (e.g., preventing modification of strings used as keys in dictionaries), enable optimizations (e.g., string interning), and maintain consistency in behavior.
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
#
# ANS: Dictionaries provide faster lookups (O(1) time complexity for key access), allow meaningful key-value associations, and are more efficient for tasks requiring unique keys.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.
#
# ANS: Tuples are preferable when you need an immutable collection, such as storing coordinates (e.g., (x, y)) or days of the week, where the data should not change.
#
# 13. How do sets handle duplicate values in Python?
#
# ANS: Sets automatically remove duplicate values when created or updated, ensuring all elements are unique.
#
# 14. How does the “in” keyword work differently for lists and dictionaries?
#
# ANS: For lists, in checks for the presence of a value (O(n) time complexity). For dictionaries, in checks for the presence of a key (O(1) time complexity).
#
# 15. Can you modify the elements of a tuple? Explain why or why not.
#
# ANS: No, tuples are immutable, so their elements cannot be modified after creation. Attempting to do so will raise an error.
#
# 16. What is a nested dictionary, and give an example of its use case.
#
# ANS: A nested dictionary is a dictionary that contains other dictionaries as values. Example: {"person": {"name": "Alice", "age": 30}}. It is useful for representing hierarchical data.
#
# 17. Describe the time complexity of accessing elements in a dictionary.
#
# ANS: Accessing elements in a dictionary has an average time complexity of O(1) due to the use of hash tables.
#
# 18. In what situations are lists preferred over dictionaries?
#
# ANS: Lists are preferred when you need an ordered collection of items, allow duplicates, or require indexing by position (e.g., list[0]).
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#
# ANS: Dictionaries were unordered in Python versions before 3.7. From Python 3.7+, they preserve insertion order, but they are still primarily accessed by keys, not positions.
#
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
#
# ANS: Lists retrieve data by index (position), while dictionaries retrieve data by keys. List access is O(1) for indexing but O(n) for searching, whereas dictionary access is O(1) for keys.
#
# #PRACTICAL QUESTION ANSWERS
#
# 1. Create a string with your name and print it.
#
# ANS: name = "John Doe"
# print(name)
#
# 2. Find the length of the string "Hello World".
#
# ANS: print(len("Hello World"))
#
# 3. Slice the first 3 characters from the string "Python Programming".
#
# ANS: text = "Python Programming"
# print(text[:3])
#
# 4. Write a code to convert the string "hello" to uppercase.
#
# ANS: print("hello".upper())
#
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple".
#
# ANS: text = "I like apple"
# print(text.replace("apple", "orange"))
#
# 6. Write a code to create a list with numbers 1 to 5 and print it.
#
# ANS: numbers = [1, 2, 3, 4, 5]
# print(numbers)
#
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].
#
# ANS: lst = [1, 2, 3, 4]
# lst.append(10)
# print(lst)
#
# 8.  Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
#
# ANS: lst = [1, 2, 3, 4, 5]
# lst.remove(3)
# print(lst)
#
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']
#
# ANS: lst = ['a', 'b', 'c', 'd']
# print(lst[1])
#
#
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].
#
# ANS: lst = [10, 20, 30, 40, 50]
# print(lst[::-1])
#
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.
#
# ANS: tup = (100, 200, 300)
# print(tup)
#
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
#
# ANS: colors = ('red', 'green', 'blue', 'yellow')
# print(colors[-2])
#
# 13.  Write a code to find the minimum number in the tuple (10, 20, 5, 15).
#
# ANS: numbers = (10, 20, 5, 15)
# print(min(numbers))
#
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
#
# ANS: animals = ('dog', 'cat', 'rabbit')
# print(animals.index('cat'))
#
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
#
# ANS: fruits = ('apple', 'banana', 'orange')
# print('kiwi' in fruits)
#
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.
#
# ANS:my_set = {'a', 'b', 'c'}
# print(my_set)
#
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
#
# ANS: my_set = {1, 2, 3, 4, 5}
# my_set.clear()
# print(my_set)
#
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
#
# ANS: my_set = {1, 2, 3, 4}
# my_set.remove(4)
# print(my_set)
#
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
#
# ANS: set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# print(set1.union(set2))
#
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
#
# ANS: set1 = {1, 2, 3}
# set2 = {2, 3, 4}
# print(set1.intersection(set2))
#
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
#
# ANS: person = {"name": "John", "age": 25, "city": "New York"}
# print(person)
#
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
#
# ANS: person = {'name': 'John', 'age': '25'}
# person['country'] = 'USA'
# print(person)
#
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
#
# ANS: person = {'name': 'Alice', 'age': '30'}
# print(person['name'])
#
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
#
# ANS: person = {'name': 'Bob', 'age': '22', 'city': 'New York'}
# del person['age']
# print(person)
#
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
#
# ANS: person = {'name': 'Alice', 'city': 'Paris'}
# print('city' in person)
#
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.
#
# ANS: my_list = [1, 2, 3]
# my_tuple = (4, 5, 6)
# my_dict = {'a': 1, 'b': 2}
# print(my_list, my_tuple, my_dict)
#
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)
#
# ANS: import random
# numbers = random.sample(range(1, 101), 5)
# numbers.sort()
# print(numbers)
#
# 28. Write a code to create a list with strings and print the element at the third index.
#
# ANS: strings = ['apple', 'banana', 'cherry', 'date']
# print(strings[2])  # Third index is 2 (0-based)
#
# 29. 29. Write a code to combine two dictionaries into one and print the result.
#
# ANS: dict1 = {'a': 1, 'b': 2}
# dict2 = {'c': 3, 'd': 4}
# combined = {**dict1, **dict2}
# print(combined)
#
# 30. Write a code to convert a list of strings into a set.
#
# ANS: string_list = ['a', 'b', 'c', 'a']
# string_set = set(string_list)
# print(string_set)
